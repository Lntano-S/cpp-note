# %%
def main() -> None:                                            
	nums: list[int] = [1, 3, 5, 7, 9]
	for i in range(len(nums)):
		print(nums[i])
		
if __name__ == "__main__":
	main()
# Out:
# 1
# 3
# 5
# 7
# 9
