# %%
def main() -> None:                                            
	nums: list[int] = [1, 3, 5, 7, 9]
	for i in range(len(nums)):
		print(nums[i])
		
if __name__ == "__main__":
	main()
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
def add_name_to_list(names: list[str], name: str) -> list[str]:
	names.append(name)
	return names

def main() -> None:
	names: list[str] = ["Yifeng Yao", "Tianyu Shu"]
	new_names: list[str] = add_name_to_list(names, "Yujie Liu")
	
	for name in names:
		print(name, end=" ")
	print("")
	for name in new_names:
		print(name, end=" ")
	#print("")
	
if __name__ == "__main__":
	main()
# Out:
# Yifeng Yao Tianyu Shu Yujie Liu
# Yifeng Yao Tianyu Shu Yujie Liu

# %%
def add_language_to_list(languages: list[str], language: str):
	languages.append(language)
	return languages

def main() -> None:
	languages: list[str] = ['C', "Python"]
	new_languages: list[str] = add_language_to_list(languages, "C++")
	
	for language in languages:
		print(language, end=" ")
	print("")
	
	for language in new_languages:
		print(language, end=" ")
	print("")
	
if __name__ == "__main__":
	main()
# Out:
# C Python C++
# C Python C++
